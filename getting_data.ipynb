# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
from bs4 import BeautifulSoup
from xlwt import Workbook
import pandas as pd
from nltk.tokenize import  word_tokenize
import numpy as np

# %%
STT = 0
wb = Workbook()
sheet1 = wb.add_sheet("crawl")
sheet1.write(0, 0, "STT")
sheet1.write(0, 1, "Tiêu Đề")
sheet1.write(0, 2, "Mô tả")
sheet1.write(0, 3, "Nội Dung")
sheet1.write(0, 4, "Ảnh Minh Họa")
sheet1.write(0, 5, "Thể Loại")

# %%
driver = webdriver.Chrome()
menu = ["thoi-su/", "tu-phap/", "quoc-te/", "kinh-te/", "tai-chinh/", "doanh-nhan/", "xa-hoi/", "moi-truong/", "giao-thong/", "do-thi/", "van-hoa/", "giai-tri/", "the-thao/", "suc-khoe/", "tu-van-sk/", "thuoc/", "phap-luat/", "tin-nong/", "phap-dinh/", "ho-so/", "dieu-tra/",
        "tieu-dung-va-du-luan/", "thi-truong-360/", "canh-bao/", "tieu-dung-thong-minh/", "xe-co/", "ban-doc/", "goc-nhin-ban-doc/", "tu-van-365/", "chinh-xach-moi/", "bat-dong-san/", "chinh-sach/", "tin-dat-lanh/", "doanh-nghiep/", "thi-truong/", "phong-thuy/", "khong-gian-xanh/", "nha-dep/", "san-giao-dich/", "the-gioi-cong-nghe/", "chuyen-doi-so/", "vien-thong/", "nhip-song-hom-nay/", "cau-chuyen-phap-luat/", "toa-an/", "dao-va-doi/",  "4-phuong/", "kham-pha/", "ho-so-tu-lieu/", "su-kien-ban-luan/", "song-xanh/"]

n = 0
for i in range(len(menu)):
    url = ("https://baophapluat.vn/" + menu[i])
    driver.get(url)
    for j in range(10):
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
        
        watch_more_bnt = driver.find_element_by_class_name("text-center")
        
        try:
            watch_more_bnt.click()
            
        except:
            pass
    page_source = BeautifulSoup(driver.page_source)
    # print(page_source)
    titles = page_source.findAll("article", class_="story story--timeline")
#     links = [link.find("a").attrs["href"] for link in titles]
    links = []
    for link in titles:
        a = link.find("a").attrs["href"]
        if a not in links:
            links.append(a)   
#     n = n + len(links)
#     print(n)

        #getting data
    for link in links:
        STT = STT + 1
        driver.get(url + link)
        page_source = BeautifulSoup(driver.page_source,"html.parser")

        # getting title
        try:
            title = page_source.find("h1", class_="article__title cms-title").text
        except:
            title = "NULL"
        # getting abstract
        try:
            abstract = page_source.find(
                "div", class_="article__summary cms-desc").text
        except:
            abstract = "NULL"
        body = page_source.find("div", class_="article__body cms-body")
        # getting content
        try:
            content = (
                body.findChildren("p", recursive=False)[0].text
                + body.findChildren("p", recursive=False)[1].text
            )
        except:
            content = "NULL"

        # getting image
        try:
            image = body.find("img").attrs["data-src"]
        except:
            image = "NULL"
        # getting category
        try:
            category = page_source.find("h1", class_="cate").text
        except:
            category = "NULL"

        sheet1.write(int(STT), 0, STT)
        sheet1.write(int(STT), 1, title)
        sheet1.write(int(STT), 2, abstract)
        sheet1.write(int(STT), 3, content)
        sheet1.write(int(STT), 4, image)
        sheet1.write(int(STT), 5, category)

        wb.save("Data1.xlsx")
        print("Tiêu đề: " + title)
        print("Mô tả: " + abstract)
        print("Nội dung: " + content)
        print("Ảnh minh họa: " + image)
        print("\n================================\n")
        print(STT)
# Out:
# Tiêu đề:  Tiếp tục triển khai toàn diện và mạnh mẽ công tác người Việt Nam ở nước ngoài
# Mô tả:  (PLVN) -  Công tác người Việt Nam ở nước ngoài thời gian tới cần tiếp tục được triển khai toàn diện và mạnh mẽ hơn, qua đó phát huy nguồn lực to lớn, tinh thần yêu nước của đồng bào ta ở nước ngoài hướng về quê hương, đất nước.
# Nội dung: Đây là một trong những yêu cầu tại Kết luận số 12-KL/TW về công tác người Việt Nam ở nước ngoài trong tình hình mới mà Bộ Chính trị vừa ban hành.Chưa phát huy được tiềm năng, thế mạnh của đồng bào ta ở nước ngoài
# Ảnh minh họa: https://image.baophapluat.vn/w800/Uploaded/2021/pwivobpc/2021_08_22/ng-viet-nn-5684.jpg
#
# ================================
#
# 2
# Tiêu đề:  Chủ tịch nước dâng hương tưởng nhớ Đại tướng Võ Nguyên Giáp
# Mô tả:  (PLVN) - Sáng 22/8, Ủy viên Bộ Chính trị, Chủ tịch nước Nguyễn Xuân Phúc dẫn đầu đoàn đại biểu lãnh đạo Đảng, Nhà nước, MTTQ Việt Nam tới dâng hương, dâng hoa tưởng niệm Đại tướng Võ Nguyên Giáp nhân kỷ niệm 110 năm Ngày sinh của Đại tướng (25/8/1911-25/8/2021).
# Nội dung: Chủ tịch nước Nguyễn Xuân Phúc cùng các đồng chí lãnh đạo Đảng, Nhà nước, MTTQ Việt Nam bày tỏ lòng thành kính trước anh linh Đại tướng Võ Nguyên Giáp - Người Anh cả của QĐND Việt Nam - vị tướng huyền thoại của dân tộc Việt Nam, vị tướng lừng danh thế giới. Chủ tịch nước và đoàn đại biểu tưởng nhớ, tri ân công lao to lớn của Đại tướng Võ Nguyễn Giáp, người đã cống hiến trọn đời cho sự nghiệp cách mạng vẻ vang của Đảng và dân tộc Việt Nam.
# Ảnh minh họa: NULL
#
# ================================
#
# 3
# Tiêu đề:  Triệt để tăng cường giãn cách xã hội để phòng chống dịch COVID-19
# Mô tả:  (PLVN) – Hôm nay (22/8), Thủ tướng Chính phủ Phạm Minh Chính vừa ký Công điện số 1099/CĐ-TTg về việc tăng cường giãn cách xã hội và các biện pháp phòng, chống dịch COVID-19.
# Nội dung: Công điện gửi Bí thư Thành ủy, Tỉnh ủy, Chủ tịch Ủy ban nhân dân Thành phố Hồ Chí Minh và các tỉnh: Bình Dương, Đồng Nai, Long An; Bộ trưởng các Bộ, Thủ trưởng cơ quan ngang bộ, cơ quan thuộc Chính phủ; Ban chỉ đạo quốc gia phòng, chống dịch COVID-19; Tổ Công tác đặc biệt của Chính phủ thực hiện công tác phòng, chống dịch COVID-19, nêu rõ:Thủ tướng Chính phủ ghi nhận, biểu dương sự vào cuộc quyết liệt của cả hệ thống chính trị và đặc biệt là sự đồng tình ủng hộ, chia sẻ và tích cực tham gia của Nhân dân, doanh nghiệp trong phòng, chống dịch tại Thành phố Hồ Chí Minh và các tỉnh: Bình Dương, Đồng Nai, Long An trong thời gian vừa qua.
# Ảnh minh họa: https://image.baophapluat.vn/w800/Uploaded/2021/igxcwwjdcvvxpcv/2021_08_21/van-hoc-20820212-3048.jpg
#
# ================================
#
# 10
# Tiêu đề:  Phát triển vaccine COVID-19 trong nước: Cần tập trung thử nghiệm, đánh giá các chỉ tiêu lâm sàng
# Mô tả:  (PLVN) -  Đó là ý kiến được đưa ra tại tọa đàm “Chuyên gia kiều bào chung tay vượt đại dịch - Vaccine Made in Vietnam” do Ủy ban Nhà nước về người Việt Nam ở nước ngoài, Bộ Ngoại giao phối hợp Ủy ban về người Việt Nam ở nước ngoài TP Hồ Chí Minh tổ chức ngày 20/8.
# Nội dung: Tọa đàm được tổ chức nhằm tiếp tục lắng nghe những ý kiến đóng góp của các chuyên gia kiều bào có chuyên môn, kinh nghiệm đối với các vấn đề liên quan đến việc nghiên cứu, thử nghiệm, quy trình, thủ tục cấp vaccine đặc biệt là trong tình thế khẩn cấp như hiện nay.Tín hiệu khả quan về vaccine sản xuất trong nước
# Ảnh minh họa: https://image.baophapluat.vn/w800/Uploaded/2021/athlraqhpghat/2021_08_21/anh-2-5831.jpg
#
# ================================
#
# 11
# Tiêu đề:  Đưa Nghị quyết Đại hội XIII của Đảng vào cuộc sống: Khơi dậy khát vọng vươn lên thoát nghèo bền vững
# Mô tả:  (PLVN) - Để giảm tỉ lệ tái nghèo, thực hiện thắng lợi mục tiêu mà Nghị quyết Đại hội XIII của Đảng đã đề ra là “tỉ lệ nghèo đa chiều duy trì mức giảm 1 - 1,5%/năm”, bên cạnh sự quyết tâm cao của Đảng và Nhà nước, cần sự nỗ lực không ngừng và tinh thần tự chủ, khát vọng vươn lên thoát nghèo của mỗi cá nhân, cộng đồng dân cư.
# Nội dung: Vẫn còn tư tưởng trông chờ, ỷ lạiMột trong những nhiệm vụ trọng tâm trong nhiệm kỳ Đại hội XIII mà Nghị quyết Đại hội XIII đã đề ra là “Khơi dậy khát vọng phát triển đất nước phồn vinh, hạnh phúc; phát huy giá trị văn hoá, sức mạnh con người Việt Nam trong sự nghiệp xây dựng và bảo vệ Tổ quốc, hội nhập quốc tế; có chính sách cụ thể phát triển văn hoá đồng bào dân tộc thiểu số; thực hiện tốt chính sách xã hội, bảo đảm an ninh xã hội, an ninh con người, tạo chuyển biến mạnh mẽ trong quản lý phát triển xã hội, thực hiện tiến bộ, công bằng xã hội, nâng cao chất lượng cuộc sống và chỉ số hạnh phúc của con người Việt Nam”.
# Ảnh minh họa: NULL
#
# ================================
#
# 12
# Tiêu đề:  KỶ NIỆM 110 NĂM NGÀY SINH ĐẠI TƯỚNG VÕ NGUYÊN GIÁP (25/8/1911 - 25/8/2021): Vị Đại tướng một đời vì đất nước
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-5ac8e90fb1a3> in <module>
#      33         STT = STT + 1
#      34         driver.get(url + link)
# ---> 35         page_source = BeautifulSoup(driver.page_source,"html.parser")
#      36
#      37         # getting title
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.159)

# %%
df = pd.read_excel("Data.xls")

# %%
df.head(5)
# Out:
#    STT                                            Tiêu Đề  \
# 0    1   Tổng lực để ngăn chặn, đẩy lùi dịch bệnh tại ...
# 1    2   Ngày làm việc thứ hai của Hội nghị Trung ương...
# 2    3   Gắn kết chặt chẽ phòng, chống tham nhũng với ...
# 3    4   Lập hội đồng xét tặng Giải thưởng Hồ Chí Minh...
# 4    5   Bộ máy còn quá cồng kềnh trong tổ chức đầu mố...
#
#                                                Mô tả  \
# 0   (PLVN) - Đó là chỉ đạo chính của Thủ tướng Ch...
# 1   (PLVN) - Ngày 6/7, Hội nghị lần thứ ba Ban Ch...
# 2   (PLVN) - Chủ trương gắn kết phòng, chống tham...
# 3   (PLVN) - Thủ tướng Chính phủ ban hành Quyết đ...
# 4   (PLVN) - Bộ trưởng Bộ Nội vụ Phạm Thị Thanh T...
#
#                                             Nội Dung  \
# 0  Văn phòng Chính phủ vừa ban hành Thông báo kết...
# 1  Thông cáo báo chí của Văn phòng Trung ương Đản...
# 2  Ngày 6/7, tại Hà Nội, Ban Nội chính Trung ương...
# 3  Hội đồng gồm 23 thành viên, do PGS.TS. Huỳnh T...
# 4  Báo cáo của Bộ Nội vụ cho biết, ngay từ những ...
#
#                                         Ảnh Minh Họa   Thể Loại
# 0  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 1                                                NaN   Thời sự
# 2  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 3                                                NaN   Thời sự
# 4                                                NaN   Thời sự

# %% [markdown]
# ## Remove punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(txt):
    txt_nopunt = "".join([c for c in txt if c not in string.punctuation])
    return txt_nopunt

# %%
df["Tiêu Đề"] = df["Tiêu Đề"].apply(lambda x: remove_punctuation(str(x)))
df["Mô tả"] = df["Mô tả"].apply(lambda y: remove_punctuation(str(y)))
df.head()
# Out:
#    STT                                            Tiêu Đề  \
# 0    1   Tổng lực để ngăn chặn đẩy lùi dịch bệnh tại T...
# 1    2   Ngày làm việc thứ hai của Hội nghị Trung ương...
# 2    3   Gắn kết chặt chẽ phòng chống tham nhũng với c...
# 3    4   Lập hội đồng xét tặng Giải thưởng Hồ Chí Minh...
# 4    5   Bộ máy còn quá cồng kềnh trong tổ chức đầu mố...
#
#                                                Mô tả  \
# 0   PLVN  Đó là chỉ đạo chính của Thủ tướng Chính...
# 1   PLVN  Ngày 67 Hội nghị lần thứ ba Ban Chấp hà...
# 2   PLVN  Chủ trương gắn kết phòng chống tham nhũ...
# 3   PLVN  Thủ tướng Chính phủ ban hành Quyết định...
# 4   PLVN  Bộ trưởng Bộ Nội vụ Phạm Thị Thanh Trà ...
#
#                                             Nội Dung  \
# 0  Văn phòng Chính phủ vừa ban hành Thông báo kết...
# 1  Thông cáo báo chí của Văn phòng Trung ương Đản...
# 2  Ngày 6/7, tại Hà Nội, Ban Nội chính Trung ương...
# 3  Hội đồng gồm 23 thành viên, do PGS.TS. Huỳnh T...
# 4  Báo cáo của Bộ Nội vụ cho biết, ngay từ những ...
#
#                                         Ảnh Minh Họa   Thể Loại
# 0  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 1                                                NaN   Thời sự
# 2  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 3                                                NaN   Thời sự
# 4                                                NaN   Thời sự

# %% [markdown]
# ## Tokenization

# %%
import re

def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

df["Tiêu Đề"] = df["Tiêu Đề"].apply(lambda x: tokenize(str(x)))
df["Mô tả"] = df["Mô tả"].apply(lambda x: tokenize(str(x)))
df.head(5)
# Out:
#    STT                                            Tiêu Đề  \
# 0    1  [, Tổng, lực, để, ngăn, chặn, đẩy, lùi, dịch, ...
# 1    2  [, Ngày, làm, việc, thứ, hai, của, Hội, nghị, ...
# 2    3  [, Gắn, kết, chặt, chẽ, phòng, chống, tham, nh...
# 3    4  [, Lập, hội, đồng, xét, tặng, Giải, thưởng, Hồ...
# 4    5  [, Bộ, máy, còn, quá, cồng, kềnh, trong, tổ, c...
#
#                                                Mô tả  \
# 0  [, PLVN, Đó, là, chỉ, đạo, chính, của, Thủ, tư...
# 1  [, PLVN, Ngày, 6, 7, Hội, nghị, lần, thứ, ba, ...
# 2  [, PLVN, Chủ, trương, gắn, kết, phòng, chống, ...
# 3  [, PLVN, Thủ, tướng, Chính, phủ, ban, hành, Qu...
# 4  [, PLVN, Bộ, trưởng, Bộ, Nội, vụ, Phạm, Thị, T...
#
#                                             Nội Dung  \
# 0  Văn phòng Chính phủ vừa ban hành Thông báo kết...
# 1  Thông cáo báo chí của Văn phòng Trung ương Đản...
# 2  Ngày 6/7, tại Hà Nội, Ban Nội chính Trung ương...
# 3  Hội đồng gồm 23 thành viên, do PGS.TS. Huỳnh T...
# 4  Báo cáo của Bộ Nội vụ cho biết, ngay từ những ...
#
#                                         Ảnh Minh Họa   Thể Loại
# 0  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 1                                                NaN   Thời sự
# 2  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 3                                                NaN   Thời sự
# 4                                                NaN   Thời sự

# %% [markdown]
# ## Remove stopword

# %%
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
stopwords = nltk.corpus.stopwords.words("vietnamese.txt")
stopwords[0:10]
# Out:
# ['cho', 'chú_thích', 'các', 'còn', 'có', 'cũng', 'của', 'dân_số', 'hai', 'hoa']

# %%
def remove_stopwords(text):
    text_clean = " ".join([word for word in text if word not in stopwords])
    return text_clean


df["New_Tiêu_Đề"] = df["Tiêu Đề"].apply(lambda x : remove_stopwords((x)))
df["New_Mô_Tả"] = df["Mô tả"].apply(lambda x : remove_stopwords((x)))
df.head(5)
# Out:
#    STT                                            Tiêu Đề  \
# 0    1  [, Tổng, lực, để, ngăn, chặn, đẩy, lùi, dịch, ...
# 1    2  [, Ngày, làm, việc, thứ, hai, của, Hội, nghị, ...
# 2    3  [, Gắn, kết, chặt, chẽ, phòng, chống, tham, nh...
# 3    4  [, Lập, hội, đồng, xét, tặng, Giải, thưởng, Hồ...
# 4    5  [, Bộ, máy, còn, quá, cồng, kềnh, trong, tổ, c...
#
#                                                Mô tả  \
# 0  [, PLVN, Đó, là, chỉ, đạo, chính, của, Thủ, tư...
# 1  [, PLVN, Ngày, 6, 7, Hội, nghị, lần, thứ, ba, ...
# 2  [, PLVN, Chủ, trương, gắn, kết, phòng, chống, ...
# 3  [, PLVN, Thủ, tướng, Chính, phủ, ban, hành, Qu...
# 4  [, PLVN, Bộ, trưởng, Bộ, Nội, vụ, Phạm, Thị, T...
#
#                                             Nội Dung  \
# 0  Văn phòng Chính phủ vừa ban hành Thông báo kết...
# 1  Thông cáo báo chí của Văn phòng Trung ương Đản...
# 2  Ngày 6/7, tại Hà Nội, Ban Nội chính Trung ương...
# 3  Hội đồng gồm 23 thành viên, do PGS.TS. Huỳnh T...
# 4  Báo cáo của Bộ Nội vụ cho biết, ngay từ những ...
#
#                                         Ảnh Minh Họa   Thể Loại  \
# 0  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 1                                                NaN   Thời sự
# 2  https://image.baophapluat.vn/w800/Uploaded/202...   Thời sự
# 3                                                NaN   Thời sự
# 4                                                NaN   Thời sự
#
#                                          New_Tiêu_Đề  \
# 0   Tổng lực ngăn chặn đẩy lùi dịch bệnh TPHCM lâ...
# 1   Ngày việc thứ Hội nghị Trung ương 3 xét thi h...
# 2   Gắn kết chặt chẽ phòng chống tham nhũng chống...
# 3   Lập hội đồng xét tặng Giải thưởng Hồ Chí Minh...
# 4          Bộ máy quá cồng kềnh tổ chức đầu mối bên
#
#                                            New_Mô_Tả
# 0   PLVN Đó chỉ đạo chính Thủ tướng Chính phủ Phạ...
# 1   PLVN Ngày 6 7 Hội nghị lần thứ ba Ban Chấp hà...
# 2   PLVN Chủ trương gắn kết phòng chống tham nhũn...
# 3   PLVN Thủ tướng Chính phủ ban hành Quyết định ...
# 4   PLVN Bộ trưởng Bộ Nội vụ Phạm Thị Thanh Trà n...

# %% [markdown]
# ## thống kê số lượng tin tức thuộc nhóm nào

# %%
a = df.groupby("Thể Loại")["Thể Loại"].count()
a.sort_values(ascending = False).head(10)
# Out:
# Thể Loại
#  Thể thao           147
#  Tin nóng           131
#  Cảnh báo           113
#  Tòa án           111
#  Đô thị              99
#  Thị trường 360      97
#  Góc nhìn            97
#  Khám phá          94
#  Chuyển đổi số       93
#  Sức khỏe            92
# Name: Thể Loại, dtype: int64

# %% [markdown]
# ## thống kê từ nào xuất hiện nhiều nhất trong các chủ đề

# %%
#create new columns
df["Str_max"] = 0
df["Number_count"] = 0

# %%
for i in range(len(df["Tiêu Đề"])):
    max = 1
    # chạy mỗi từ và đếm số lần xuất hiện trong "Tiêu Đề thứ i"
    for j in range(1,len(df["Tiêu Đề"][i])-1,1):
        a = df["Tiêu Đề"][i].count(df["Tiêu Đề"][i][j])
        if a > max:
            max = a
    # tìm được chữ có số lần xuất hiện nhiều nhất và gán cho cột mới được tạo       
    for j in range(1,len(df["Tiêu Đề"][i])-1,1):
        if df["Tiêu Đề"][i].count(df["Tiêu Đề"][i][j]) == max:
            df["Number_count"][i] = max
            df["Str_max"][i]= df["Tiêu Đề"][i][j]
        else: 
            pass
# Out:
# <ipython-input-19-db831e25150e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Number_count"][i] = max
# <ipython-input-19-db831e25150e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Str_max"][i]= df["Tiêu Đề"][i][j]
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
b = df.groupby(["Thể Loại","Str_max"])["Str_max"].count()
b.sort_values(ascending = False).head(50)
# Out:
# Thể Loại                Str_max
#  Thị trường 360         vàng        16
#  Giáo dục               2021        14
#  Tài chính              19          13
#  Tư vấn 365             không       13
#  Giao thông             xe          13
#  Thể thao               Nam         13
#  Thị trường 360         tuần        11
#  Sức khỏe               19          10
#  Thể thao               UAE          9
#  Thị trường 360         giá          9
#  Môi trường             và           9
#  Pháp đình              tù           8
#  Nhịp sống 24/7         19           8
#  Tin nóng               sản          8
#  Chuyển đổi số          Bluezone     7
#  Thuốc                  thư          7
#  Sức khỏe               2            7
#  Quốc tế                19           7
#  Sức khỏe               mới          7
#  Chuyển đổi số          số           6
#  Pháp đình              án           6
#  Chuyển đổi số          minh         6
#  Thị trường 360         lượng        6
#  Doanh nhân             19           6
#  Pháp đình              đồng         6
#  Quốc tế                Nga          5
#  Ô tô                   Nam          5
#  Giao thông             người        5
#  Tiêu dùng thông minh   đồng         5
#  Thị trường 360         giảm         5
#  Ô tô                   2021         5
#  Chuyển đổi số          19           5
#  Pháp đình              19           5
#  Giao thông             lại          5
#  Pháp đình              tiền         5
#  Chính sách             cư           5
#                         khu          5
#  Xe                     đồng         5
#  Sức khỏe               7            5
#  Giao thông             tải          4
#  Tòa án               nào          4
#  Cảnh báo               hàng         4
#                         gốc          4
#  Giao thông             vong         4
#  Cảnh báo               giả          4
#  Sức khỏe               ca           4
#  Chính sách             đai          4
#  Tin nóng               người        4
#  Đô thị                 2021         4
#  Thể thao               gia          4
# Name: Str_max, dtype: int64

# %% [markdown]
# ## Find infomation of newspaper

# %%
n = input("nhập từ khóa: ")
n = n.split(" ")

for k in range(len(n)):
    for i in range(len(df["Tiêu Đề"])):
        #so sánh từng chữ trong N với các chữ trong tiêu đề thứ i
        for j in range(len(df["Tiêu Đề"][i])):
            if n[k] == df["Tiêu Đề"][i][j]:
                print(" ".join(df["Tiêu Đề"][i]), end = '')
                print("--Thể Loại:",df["Thể Loại"][i])
# Out:
# nhập từ khóa: vàng
# vàng
#  Chương trình Tay hòm chìa khóa chính thức phát sóng trên khung giờ vàng VTV1 vào tối 7 5 --Thể Loại:  Tài chính
